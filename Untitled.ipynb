# %%
import csv
import os
import matplotlib.pyplot as plt
import webbpsf
import numpy as np
import os
from numpy import genfromtxt
import pysynphot as S
import matplotlib.pyplot as plt
import pyfits
from astropy.io import fits
# Out:
# /suphys/klam8364/.conda/envs/astroconda/lib/python2.7/site-packages/pyfits/__init__.py:22: PyFITSDeprecationWarning: PyFITS is deprecated, please use astropy.io.fits
#   PyFITSDeprecationWarning)  # noqa

# %%
# %pylab inline
# Monochromatic PSF of aperture mask
ni=webbpsf.NIRISS()
ni.filter='F380M' #'F430M'
ni.pupil_mask='MASK_NRM'
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
bp = S.Box(50000, 50000)
src = webbpsf.specFromSpectralType('G0V', catalog='phoenix')
src_ext=src*S.Extinction(30,'mwdense')
src_ext_n=src_ext.renorm(10,'ABMag',bp)
flatsp = S.FlatSpectrum(18, fluxunits='abmag')
flatsp_ext=src*S.Extinction(30,'mwdense')
flatsp_ext_n=flatsp_ext.renorm(10,'ABMag',bp)

# %%
#ni.options['source_offset_r'] = 0.3 # offset in arcseconds
#ni.options['source_offset_theta'] = 45. # degrees counterclockwise from instrumental +Y␣→in the science frame
ni.options['jitter']='gaussian'
ni.options['jitter_sigma']=0.009    #in arcsec, default 0.007

# %%
result=ni.calc_psf(source=src_ext_n, fov_arcsec=1, oversample=4,display=True)
resultn=ni.calc_psf(source=src_ext_n, fov_arcsec=1, oversample=4,display=True, normalize='exit_pupil')
bh=ni.calc_psf(source=flatsp_ext_n, fov_arcsec=1, oversample=4,display=True)
# Out:
# /suphys/klam8364/.conda/envs/astroconda/lib/python2.7/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
result.writeto('Resultpsf')
# Out:
# WARNING: VerifyWarning: Card is too long, comment will be truncated. [astropy.io.fits.card]
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-87-7a68ef00fb36> in <module>()
# ----> 1 result.writeto('Resultpsf')
#
# /suphys/klam8364/.local/lib/python2.7/site-packages/astropy-2.0.2-py2.7-linux-x86_64.egg/astropy/utils/decorators.pyc in wrapper(*args, **kwargs)
#     505                         # one with the name of the new argument to the function
#     506                         kwargs[new_name[i]] = value
# --> 507             return function(*args, **kwargs)
#     508
#     509         return wrapper
#
# /suphys/klam8364/.local/lib/python2.7/site-packages/astropy-2.0.2-py2.7-linux-x86_64.egg/astropy/io/fits/hdu/hdulist.pyc in writeto(self, fileobj, output_verify, overwrite, checksum)
# ...

# %%
#pyfits.PrimaryHDU(data=result['DET_SAMP'].data, header=result['DET_SAMP'].header).writeto('ResultsHDUpsf')
hdul=pyfits.open('psfresult'+str(1))
hdul.info()
# Out:
# Filename: psfresult1
# No.    Name         Type      Cards   Dimensions   Format
# 0    OVERSAMP    PrimaryHDU      69   (364, 364)   float64
# 1    DET_SAMP    ImageHDU        71   (91, 91)     float64

# %%
data0=hdul[0].data
data0.shape
# Out:
# (364, 364)

# %%
my_data = genfromtxt('RA_DEC_L_M_mag.csv', delimiter=',')       #RA_DEC_L_M_mag.csv or RA_DEC.csv Need to include up to 5.2" radius

# %%
my_data.shape
# Out:
# (42, 4)

# %%
RA=my_data[:,0]
DEC=my_data[:,1]
L_mag=my_data[:,2]
M_mag=my_data[:,3]

# %%
plt.plot(RA, DEC, 'ro')
plt.show()
plt.xlabel('RA (arcseconds)')
plt.ylabel('DE (arcseconds)')
plt.title('L&M bands in Galactic Centre')
# Out:
# Text(0.5,1,u'L&M bands in Galactic Centre')

# %%
def cart2pol(x, y):
    rho = np.sqrt(x**2 + y**2)
    phi = np.arctan2(y, x)
    return(rho, phi)
(r, thetar)=cart2pol(RA,DEC)

# %%
import math
theta=degrees(thetar)    #radians to degrees
theta_y=theta+90         #Rotate to y axis frame

# %%
#Generate a FOR loop to write out pdfs for each position in (r,theta).

for i in range(len(r)):
    ni.options['source_offset_r'] = r[i] # offset in arcseconds
    ni.options['source_offset_theta'] = theta_y[i] # degrees counterclockwise from instrumental +Y␣→in the science frame
    resulti=ni.calc_psf(source=src_ext_n, fov_arcsec=6, oversample=4) #larger field of view? Perhaps 12
    resulti.writeto('psfresults'+str(i))

# %%
#Write out FITS files for each psf and then overlap it using table data.
data=[0]*len(r)
hdul=[0]*len(r)
for i in range(len(r)):
    hdul[i]=pyfits.open('psfresults'+str(i))
    data[i]=hdul[i][0].data
data[1].shape

# %%
from scipy.interpolate import interp1d           #Lambda to Jansky
lambd= [0.36,0.44,0.5556,0.70,0.90,1.215,1.654,2.157,2.179,3.547, 3.761,4.769,8.756,10.472,11.653,20.130]
jansky0=[1880,4440,3540, 2880,2240,1630, 1050, 667,  655,  276, 248,  160,  50.0, 35.2,  28.6,  9.70  ]
jansky=interp1d(lambd, jansky0, kind='cubic')    #Interpolation
xnew=np.linspace(0.36, 20.130, num=90)
plt.plot(lambd,jansky0,'o',xnew,jansky(xnew),'--')
plt.show()

# %%
lambd_array=np.linspace(3.726,3.931,num=100)   #Assuming constant bandwith between filter wavelengths
mean_jansky=np.mean(jansky(lambd_array))
star_flx  = 10**(L_mag/(-2.5)) * mean_jansky  #Units in Jansky
f=(3e8/3.828e-6)
pht_rate=10**(23)*f*star_flx/(6.626e-34*f*10**(7)) #Units in s-1.cm-2

# %%
#Aperture mask size in cm2?

# %%
final_image = np.zeros(shape=data[0].shape)
#need photon counts for each magnitude
for image in data:
    final_image += image

# %%
#image.shape
final_image.shape
# Out:
# (364, 364)

# %%
image_hist = plt.hist(final_image.flatten())

# %%
plt.imshow(final_image)
plt.colorbar()

# %%
outfile = 'Starry field of view'

hdu = fits.PrimaryHDU(final_image)
hdu.writeto(outfile, clobber=True)
# Out:
# WARNING: AstropyDeprecationWarning: "clobber" was deprecated in version 2.0 and will be removed in a future version. Use argument "overwrite" instead. [astropy.utils.decorators]
