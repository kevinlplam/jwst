# %%
import csv
import os
import matplotlib.pyplot as plt

import numpy as np
from numpy import genfromtxt

# %%
import webbpsf
import numpy as np
import os
# %pylab inline
# Monochromatic PSF of aperture mask
ni=webbpsf.NIRISS()
ni.filter='F380M' #'F430M'
ni.pupil_mask='MASK_NRM'
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pysynphot as S
import matplotlib.pyplot as plt
bp = S.Box(50000, 50000)
src = webbpsf.specFromSpectralType('G0V', catalog='phoenix')
src_ext=src*S.Extinction(30,'mwdense')
src_ext_n=src_ext.renorm(10,'ABMag',bp)
flatsp = S.FlatSpectrum(18, fluxunits='abmag')
flatsp_ext=src*S.Extinction(30,'mwdense')
flatsp_ext_n=flatsp_ext.renorm(10,'ABMag',bp)

# %%
#ni.options['source_offset_r'] = 0.3 # offset in arcseconds
#ni.options['source_offset_theta'] = 45. # degrees counterclockwise from instrumental +Y␣→in the science frame
ni.options['jitter']='gaussian'
ni.options['jitter_sigma']=0.009    #in arcsec, default 0.007

# %%
result=ni.calc_psf(source=src_ext_n, fov_arcsec=1, oversample=4,display=True)
resultn=ni.calc_psf(source=src_ext_n, fov_arcsec=1, oversample=4,display=True, normalize='exit_pupil')
bh=ni.calc_psf(source=flatsp_ext_n, fov_arcsec=1, oversample=4,display=True)
# Out:
# /suphys/klam8364/.conda/envs/astroconda/lib/python2.7/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
result.writeto('Resultpsf')
# Out:
# WARNING: VerifyWarning: Card is too long, comment will be truncated. [astropy.io.fits.card]
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-30-7a68ef00fb36> in <module>()
# ----> 1 result.writeto('Resultpsf')
#
# /suphys/klam8364/.local/lib/python2.7/site-packages/astropy-2.0.2-py2.7-linux-x86_64.egg/astropy/utils/decorators.pyc in wrapper(*args, **kwargs)
#     505                         # one with the name of the new argument to the function
#     506                         kwargs[new_name[i]] = value
# --> 507             return function(*args, **kwargs)
#     508
#     509         return wrapper
#
# /suphys/klam8364/.local/lib/python2.7/site-packages/astropy-2.0.2-py2.7-linux-x86_64.egg/astropy/io/fits/hdu/hdulist.pyc in writeto(self, fileobj, output_verify, overwrite, checksum)
#     876         # file object that's open to write only, or in append/update modes
#     877         # but only if the file doesn't exist.
# --> 878         fileobj = _File(fileobj, mode='ostream', overwrite=overwrite)
#     879         hdulist = self.fromfile(fileobj)
#     880         try:
#
# /suphys/klam8364/.local/lib/python2.7/site-packages/astropy-2.0.2-py2.7-linux-x86_64.egg/astropy/utils/decorators.pyc in wrapper(*args, **kwargs)
#     505                         # one with the name of the new argument to the function
#     506                         kwargs[new_name[i]] = value
# --> 507             return function(*args, **kwargs)
#     508
#     509         return wrapper
#
# /suphys/klam8364/.local/lib/python2.7/site-packages/astropy-2.0.2-py2.7-linux-x86_64.egg/astropy/io/fits/file.pyc in __init__(self, fileobj, mode, memmap, overwrite, cache)
#     148             self._open_fileobj(fileobj, mode, overwrite)
#     149         elif isinstance(fileobj, string_types):
# --> 150             self._open_filename(fileobj, mode, overwrite)
#     151         else:
#     152             self._open_filelike(fileobj, mode, overwrite)
#
# /suphys/klam8364/.local/lib/python2.7/site-packages/astropy-2.0.2-py2.7-linux-x86_64.egg/astropy/io/fits/file.pyc in _open_filename(self, filename, mode, overwrite)
#     478
#     479         if mode == 'ostream':
# --> 480             self._overwrite_existing(overwrite, None, True)
#     481
#     482         if os.path.exists(self.name):
#
# /suphys/klam8364/.local/lib/python2.7/site-packages/astropy-2.0.2-py2.7-linux-x86_64.egg/astropy/io/fits/file.pyc in _overwrite_existing(self, overwrite, fileobj, closed)
#     399                     os.remove(self.name)
#     400             else:
# --> 401                 raise IOError("File {!r} already exists.".format(self.name))
#     402
#     403     def _open_fileobj(self, fileobj, mode, overwrite):
#
# IOError: File 'Resultpsf' already exists.

# %%
import pyfits
#pyfits.PrimaryHDU(data=result['DET_SAMP'].data, header=result['DET_SAMP'].header).writeto('ResultsHDUpsf')
hdul=pyfits.open('Resultpsf')
hdul.info()
# Out:
# Filename: Resultpsf
# No.    Name         Type      Cards   Dimensions   Format
# 0    OVERSAMP    PrimaryHDU      68   (60, 60)     float64
# 1    DET_SAMP    ImageHDU        70   (15, 15)     float64

# %%
data0=hdul[0].data
data0.shape
# Out:
# (60, 60)

# %%
my_data = genfromtxt('RA_DEC_L_M_mag.csv', delimiter=',')       #RA_DEC_L_M_mag.csv or RA_DEC.csv

# %%
my_data.shape
# Out:
# (42, 4)

# %%
RA=my_data[:,0]
DEC=my_data[:,1]
L_mag=my_data[:,2]
M_mag=my_data[:,3]

# %%
plt.plot(RA, DEC, 'ro')
plt.show()
plt.xlabel('RA (arcseconds)')
plt.ylabel('DE (arcseconds)')
plt.title('L&M bands in Galactic Centre')
# Out:
# Text(0.5,1,u'L&M bands in Galactic Centre')

# %%
def cart2pol(x, y):
    rho = np.sqrt(x**2 + y**2)
    phi = np.arctan2(y, x)
    return(rho, phi)
(r, theta)=cart2pol(RA,DEC)

# %%
# Out:
# array([ 1.76269324,  2.66549807,  1.75810806,  2.82375193, -2.8582918 ,
#        -1.51606986, -1.91555716,  1.08408664, -0.54536678, -0.73099271,
#         0.76296884, -1.35888437,  1.7179422 , -1.32084797, -0.33973935,
#        -1.6925461 , -1.8227206 , -2.01283302, -2.12428122, -2.66052243,
#        -1.55677775, -0.61814404, -1.59477168, -2.441655  ,  2.73537159,
#        -2.83981446,  0.7546357 , -2.37572774, -2.57783229, -0.01825907,
#        -0.61315088, -0.64627269,  3.09532971, -2.43604607, -3.0027161 ,
#         0.86528191,  3.03061269, -2.94255129, -0.0918169 ,  0.89874778,
#        -2.51462968,  0.38129124])

# %%
#Generate a FOR loop to write out pdfs for each position in (r,theta). Also need to 'normalise'? for different intensities
#Write out FITS files for each psf and then overlap it using table data.
